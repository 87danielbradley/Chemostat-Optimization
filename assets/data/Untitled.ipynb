# %%
import pandas as pd

# %%
df = pd.read_csv('data_optday.csv')
df.head(1)
# Out:
#    Day nutrient     days2     days3     days4  days5     days6     days7  \
# 0    1      glc  0.000011  0.000014  0.000034    0.0  0.000114  0.000055
#
#      days8     days9    days10
# 0  0.00017  0.000054  0.000001

# %%
LoD = []
myDict = {}
for i in range(0,len(df.Day)):
    
    myDict = {
        "day": df.Day[i],
        "nutrient": df.nutrient[i],
        "days2": df.days2[i],
        "days3": df.days3[i],
        "days4": df.days4[i],
        "days5": df.days5[i],
        "days6": df.days6[i],
        "days7": df.days7[i],
        "days8": df.days8[i],
        "days9": df.days9[i],
        "days10": df.days10[i]
    }
    LoD.append(myDict)
LoD
# Out:
# [{'day': 1,
#   'nutrient': 'glc',
#   'days2': 1.09e-05,
#   'days3': 1.4300000000000002e-05,
#   'days4': 3.3574e-05,
#   'days5': 0.0,
#   'days6': 0.00011383299999999999,
#   'days7': 5.45e-05,
#   'days8': 0.00016999999999999999,
#   'days9': 5.44e-05,
#   'days10': 1e-06},
#  {'day': 1,
#   'nutrient': 'gln',
#   'days2': 1.47e-05,
#   'days3': 3.9200000000000004e-05,
#   'days4': 1.3980999999999999e-05,
#   'days5': 7.99e-05,
#   'days6': 0.011725089,
#   'days7': 0.06268025299999999,
#   'days8': 0.187745702,
#   'days9': 0.08427802699999999,
#   'days10': 0.28429899999999997},
#  {'day': 2,
#   'nutrient': 'glc',
#   'days2': 5.93e-05,
#   'days3': 5.96e-05,
#   'days4': 7.0605e-05,
#   'days5': 0.0,
#   'days6': 6.59e-05,
#   'days7': 7.950000000000001e-05,
#   'days8': 2.62e-05,
#   'days9': 0.0,
#   'days10': 0.0},
#  {'day': 2,
#   'nutrient': 'gln',
#   'days2': 2.07e-05,
#   'days3': 1.17e-05,
#   'days4': 0.08272,
#   'days5': 0.0,
#   'days6': 0.12457917800000001,
# ...

# %%
df.to_json(index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-144e732832ec> in <module>
# ----> 1 df.to_json(index=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_json(self, path_or_buf, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index)
#    2422             lines=lines,
#    2423             compression=compression,
# -> 2424             index=index,
#    2425         )
#    2426
#
# ~\Anaconda3\lib\site-packages\pandas\io\json\_json.py in to_json(path_or_buf, obj, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index)
#      50     if not index and orient not in ["split", "table"]:
#      51         raise ValueError(
# ---> 52             "'index=False' is only valid when 'orient' is " "'split' or 'table'"
#      53         )
#      54
#
# ...
